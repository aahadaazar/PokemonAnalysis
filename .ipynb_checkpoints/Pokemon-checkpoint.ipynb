# %%
import pandas as pd;
pokemon_data = pd.read_csv('./PokemonData.csv');


def regionChecker(argument):
    switcher = { 
        1: "Kanto",
        2: "Johto",
        3: "Hoenn",
        4: "Sinnoh",
        5: "Unova",
        6: "Kalos",
    } 
    return switcher.get(argument['Generation'], "nothing");


data = pd.DataFrame(pokemon_data);
data = data.rename(columns={'Num': 'Pokedex_Index'});
data = data.set_index('Pokedex_Index');
data['Region_of_Origin'] = data.apply (lambda row: regionChecker(row), axis=1);
data
# Out:
#                                 Name    Type1   Type2  HP  Attack  Defense  \
# Pokedex_Index
# 1                          Bulbasaur    Grass  Poison  45      49       49
# 2                            Ivysaur    Grass  Poison  60      62       63
# 3                           Venusaur    Grass  Poison  80      82       83
# 3              VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4                         Charmander     Fire     NaN  39      52       43
# ...                              ...      ...     ...  ..     ...      ...
# 719                          Diancie     Rock   Fairy  50     100      150
# 719              DiancieMega Diancie     Rock   Fairy  50     160      110
# 720              HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 720               HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 721                        Volcanion     Fire   Water  80     110      120
#
#                SpAtk  SpDef  Speed  Generation  Legendary Region_of_Origin
# Pokedex_Index
# 1                 65     65     45           1      False            Kanto
# 2                 80     80     60           1      False            Kanto
# 3                100    100     80           1      False            Kanto
# 3                122    120     80           1      False            Kanto
# 4                 60     50     65           1      False            Kanto
# ...              ...    ...    ...         ...        ...              ...
# 719              100    150     50           6       True            Kalos
# 719              160    110    110           6       True            Kalos
# 720              150    130     70           6       True            Kalos
# 720              170    130     80           6       True            Kalos
# 721              130     90     70           6       True            Kalos
#
# [800 rows x 12 columns]
